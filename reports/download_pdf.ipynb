# %%
import sys
print(sys.executable)
# Out:
# /home/bokushi/anaconda3/envs/cminer/bin/python

# %%
import requests

# %%
response = requests.get(r'https://iopscience.iop.org/article/10.1088/1742-6596/1393/1/012148/pdf')

# %%
response
# Out:
# <Response [200]>

# %%
import os

# %%
os.getcwd()
# Out:
# '/home/bokushi/bokushiProjects/CoatingMiner/reports'

# %%
with open(r'aaa.pdf', 'wb') as file:
    for chunk in response.iter_content(chunk_size=8192):
        if chunk:
            file.write(chunk)
