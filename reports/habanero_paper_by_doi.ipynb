# %%
from habanero import Crossref

# %%
cr = Crossref()

# %%
test_doi = 'doi:10.1088/1742-6596/1393/1/012148'
test_work = cr.works(ids=test_doi)

# %%
aa = None

if aa:
    print('s')
else:
    print('n')
# Out:
# n

# %%
test_work['message']['author']
# Out:
# [{'given': 'E L',
#   'family': 'Vardanyan',
#   'sequence': 'first',
#   'affiliation': []},
#  {'given': 'K N',
#   'family': 'Ramazanov',
#   'sequence': 'additional',
#   'affiliation': []},
#  {'given': 'A Yu',
#   'family': 'Nazarov',
#   'sequence': 'additional',
#   'affiliation': []},
#  {'given': 'R Sh',
#   'family': 'Nagimov',
#   'sequence': 'additional',
#   'affiliation': []}]

# %%
links = test_work['message'].get('link', [])
links
# Out:
# [{'URL': 'https://iopscience.iop.org/article/10.1088/1742-6596/1393/1/012148/pdf',
#   'content-type': 'application/pdf',
#   'content-version': 'vor',
#   'intended-application': 'text-mining'},
#  {'URL': 'https://iopscience.iop.org/article/10.1088/1742-6596/1393/1/012148',
#   'content-type': 'text/html',
#   'content-version': 'vor',
#   'intended-application': 'text-mining'},
#  {'URL': 'https://iopscience.iop.org/article/10.1088/1742-6596/1393/1/012148',
#   'content-type': 'text/html',
#   'content-version': 'vor',
#   'intended-application': 'text-mining'},
#  {'URL': 'https://iopscience.iop.org/article/10.1088/1742-6596/1393/1/012148/pdf',
#   'content-type': 'application/pdf',
#   'content-version': 'vor',
#   'intended-application': 'text-mining'},
#  {'URL': 'https://iopscience.iop.org/article/10.1088/1742-6596/1393/1/012148/pdf',
#   'content-type': 'application/pdf',
#   'content-version': 'vor',
#   'intended-application': 'syndication'},
#  {'URL': 'https://iopscience.iop.org/article/10.1088/1742-6596/1393/1/012148/pdf',
#   'content-type': 'application/pdf',
#   'content-version': 'vor',
#   'intended-application': 'similarity-checking'},
#  {'URL': 'https://iopscience.iop.org/article/10.1088/1742-6596/1393/1/012148',
#   'content-type': 'text/html',
#   'content-version': 'vor',
#   'intended-application': 'similarity-checking'},
#  {'URL': 'https://iopscience.iop.org/article/10.1088/1742-6596/1393/1/012148/pdf',
#   'content-type': 'application/pdf',
#   'content-version': 'vor',
#   'intended-application': 'similarity-checking'}]

# %%
if len(links) > 0:
    print('ss')
else:
    print('nn')
# Out:
# ss

# %%
for l in links:
    print(l.get('URL', ''))
# Out:
# https://iopscience.iop.org/article/10.1088/1742-6596/1393/1/012148/pdf
# https://iopscience.iop.org/article/10.1088/1742-6596/1393/1/012148
# https://iopscience.iop.org/article/10.1088/1742-6596/1393/1/012148
# https://iopscience.iop.org/article/10.1088/1742-6596/1393/1/012148/pdf
# https://iopscience.iop.org/article/10.1088/1742-6596/1393/1/012148/pdf
# https://iopscience.iop.org/article/10.1088/1742-6596/1393/1/012148/pdf
# https://iopscience.iop.org/article/10.1088/1742-6596/1393/1/012148
# https://iopscience.iop.org/article/10.1088/1742-6596/1393/1/012148/pdf

# %%
def get_links(doi):
    try:
        work = cr.works(ids=doi)
        work_data = work['message']
        
        # Check for full-text links
        links = work_data.get('link', [])
        
#         if links:
#             print(f"Found {len(links)} full-text links for {doi}")
#             for link in links:
#                 content_type = link.get('content-type', 'unknown')
#                 url = link.get('URL', 'No URL')
#                 intended = link.get('intended-application', 'general')
                
#                 print(f"  • Type: {content_type}")
#                 print(f"    URL: {url}")
#                 print(f"    Intended for: {intended}")
#                 print()
#             return links
#         else:
#             print(f"No direct full-text links found for {doi}")
#             return []
            
#     except Exception as e:
#         print(f"Error fetching {doi}: {e}")
#         return []

# # Test with different types of papers
# dois = [
#     "10.1371/journal.pone.0171501",  # PLOS ONE (Open Access)
#     "10.1038/nature12373",            # Nature (subscription)
#     "10.1101/2023.01.01.522345"       # bioRxiv (preprint)
# ]

# for doi in dois:
#     get_fulltext_links(doi)
#     time.sleep(1)  # Be polite
